# %% [markdown]
# # Download dataset from kaggle <br>
# ref: https://www.kaggle.com/c/quora-question-pairs/data <br>
#
# Data fields <br>
#
#
#
# *   id - the id of a training set question pair
# *   qid1, qid2 - unique ids of each question (only available in train.csv)
# *   question1, question2 - the full text of each question
# *   is_duplicate - the target variable, set to 1 if question1 and question2 have essentially the same meaning, and 0 otherwise.

# %%
import os
from google.colab import drive

drive.mount('/content/drive')
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/kaggle"
# %cd /content/drive/My Drive/colab_data/datasets
if (not os.path.isdir('quora-question-pairs')):
  os.mkdir('quora-question-pairs')
# %cd quora-question-pairs
# !kaggle competitions download -c quora-question-pairs
# !unzip \*.zip  && rm *.zip

# %% [markdown]
# # Load and clean data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/colab_data/datasets/quora-question-pairs
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/colab_data/datasets/quora-question-pairs

# %%
import os
import pandas as pd
import spacy
import re

from time import time

from nltk.stem import SnowballStemmer
snowStem=SnowballStemmer('english')

pd.set_option('display.max_colwidth', None)
ROOT_DIR = '/content/drive/My Drive/colab_data/datasets/quora-question-pairs'

# %%
df = pd.read_csv(os.path.join(ROOT_DIR,'train.csv'))
print(df.shape)
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# (404290, 6)
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
df.head()
# Out:
#    id  ...  is_duplicate
# 0   0  ...             0
# 1   1  ...             0
# 2   2  ...             0
# 3   3  ...             0
# 4   4  ...             0
#
# [5 rows x 6 columns]

# %%
nlp = spacy.load('en', disable=['ner', 'parser'])

def cleaning(doc):
    txt = [snowStem.stem(token.text) for token in doc]
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['question1'])

t = time()
txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
df["clean_question1"] = txt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-34e9124ef066> in <module>()
#       2
#       3 t = time()
# ----> 4 txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]
#       5 print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
#       6 df["clean_question1"] = txt
#
# <ipython-input-6-34e9124ef066> in <listcomp>(.0)
#       2
#       3 t = time()
# ----> 4 txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]
#       5 print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
#       6 df["clean_question1"] = txt
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in pipe(self, texts, as_tuples, n_threads, batch_size, disable, cleanup, component_cfg, n_process)
#     817         original_strings_data = None
#     818         nr_seen = 0
# --> 819         for doc in docs:
#     820             yield doc
#     821             if cleanup:
#
# pipes.pyx in pipe()
#
# /usr/local/lib/python3.6/dist-packages/spacy/util.py in minibatch(items, size)
#     479     while True:
#     480         batch_size = next(size_)
# --> 481         batch = list(itertools.islice(items, int(batch_size)))
#     482         if len(batch) == 0:
#     483             break
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in <genexpr>(.0)
#     802         else:
#     803             # if n_process == 1, no processes are forked.
# --> 804             docs = (self.make_doc(text) for text in texts)
#     805             for pipe in pipes:
#     806                 docs = pipe(docs)
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in make_doc(self, text)
#     455
#     456     def make_doc(self, text):
# --> 457         return self.tokenizer(text)
#     458
#     459     def _format_docs_and_golds(self, docs, golds):
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# doc.pyx in spacy.tokens.doc.Doc.__init__()
#
# doc.pyx in spacy.tokens.doc._get_chunker()
#
# /usr/local/lib/python3.6/dist-packages/spacy/util.py in get_lang_class(lang)
#      69     # Check if language is registered / entry point is available
#      70     if lang in registry.languages:
# ---> 71         return registry.languages.get(lang)
#      72     else:
#      73         try:
#
# /usr/local/lib/python3.6/dist-packages/catalogue.py in get(self, name)
#      93             if from_entry_point:
#      94                 return from_entry_point
# ---> 95         namespace = list(self.namespace) + [name]
#      96         if not check_exists(*namespace):
#      97             err = "Cant't find '{}' in registry {}. Available names: {}"
#
# KeyboardInterrupt:

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['question2'])

t = time()
txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
df["clean_question2"] = txt

# %%
df = df.dropna().reset_index(drop=True)
print(df.isnull().sum())

# %%
df_clean = df.drop(columns=['question1', 'question2'])
df_clean.head()

# %%
df_clean.to_csv("train_clean.csv")

# %%
df_clean = pd.read_csv(os.path.join(ROOT_DIR,'train_clean.csv'))
df_clean.head()
# Out:
#    Unnamed: 0  ...                                                                    clean_question2
# 0           0  ...                            what is the step by step guid to invest in share market
# 1           1  ...  what would happen if the indian govern stole the kohinoor koh i noor diamond back
# 2           2  ...                              how can internet speed be increas by hack through dns
# 3           3  ...                                        find the remaind when math math is divid by
# 4           4  ...                                              which fish would surviv in salt water
#
# [5 rows x 7 columns]

# %% [markdown]
# # Build Vocab and train word2vec

# %%
from gensim.models.phrases import Phrases, Phraser

text = list(df_clean['clean_question1']) + list(df_clean['clean_question2'])
sent = [row.split() for row in text]
phrases = Phrases(sent, min_count=30, progress_per=10000)
bigram = Phraser(phrases)
sentences = bigram[sent]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3c0e15866160> in <module>()
#       4 sent = [row.split() for row in text]
#       5 phrases = Phrases(sent, min_count=30, progress_per=10000)
# ----> 6 bigram = Phraser(phrases)
#       7 sentences = bigram[sent]
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py in __init__(self, phrases_model)
#     770         logger.info('source_vocab length %i', len(phrases_model.vocab))
#     771         count = 0
# --> 772         for bigram, score in phrases_model.export_phrases(corpus, self.delimiter, as_tuples=True):
#     773             if bigram in self.phrasegrams:
#     774                 logger.info('Phraser repeat %s', bigram)
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py in export_phrases(self, sentences, out_delimiter, as_tuples)
#     546             # keeps only not None scores
#     547             filtered = ((words, score) for words, score in bigrams if score is not None)
# --> 548             for words, score in filtered:
#     549                 if as_tuples:
#     550                     yield (tuple(words), score)
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py in <genexpr>(.0)
#     545             bigrams = analyze_sentence(sentence)
#     546             # keeps only not None scores
# --> 547             filtered = ((words, score) for words, score in bigrams if score is not None)
#     548             for words, score in filtered:
#     549                 if as_tuples:
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py in analyze_sentence(self, sentence, threshold, common_terms, scorer)
#     164                     wordb=word,
#     165                     components=chain,
# --> 166                     scorer=scorer,
#     167                 )
#     168                 if score > threshold:
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py in score_item(self, worda, wordb, components, scorer)
#     123                 return scorer(
#     124                     worda_count=float(vocab[worda]),
# --> 125                     wordb_count=float(vocab[wordb]),
#     126                     bigram_count=float(vocab[bigram]))
#     127         return -1
#
# KeyboardInterrupt:

# %%
import multiprocessing
from gensim.models import Word2Vec
cores = multiprocessing.cpu_count()

# %%
w2v_model = Word2Vec(min_count=5,
                     window=5,
                     size=200,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))

# %%
token2Id = {}
id2token = {}

index = 1

for vocab in w2v_model.wv.vocab.keys():

  token2Id[vocab] = index
  id2token[str(index)] = vocab
  index += 1

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))

# %%
w2v_model.init_sims(replace=True)
w2v_wv = w2v_model.wv

# %%
import json
with open('token2Id.json', 'w') as json_file:
        json.dump(token2Id, json_file, indent=4)
with open('id2token.json', 'w') as json_file:
        json.dump(id2token, json_file, indent=4)

w2v_wv.save("w2v-200d.kv")

# %%
token2Id = {}
id2token = {}

# %%
import json
with open('token2Id.json') as json_file:
        token2Id = json.load(json_file)

with open('id2token.json') as json_file:
        id2token = json.load(json_file)

# %% [markdown]
# # Proprocess Text

# %%
def preprocess(text):
  ids = [token2Id[word] for word in text.split(' ') if word in token2Id.keys()]
  return ids

# %%
preprocessed = [preprocess(row) for row in df_clean['clean_question1']]
df_clean["question1"] = preprocessed
preprocessed = [preprocess(row) for row in df_clean['clean_question2']]
df_clean["question2"] = preprocessed
df_clean.head()
# Out:
#    Unnamed: 0  ...                                                          question2
# 0           0  ...                         [1, 2, 3, 4, 5, 4, 6, 7, 8, 9, 1454, 2291]
# 1           1  ...  [1, 100, 259, 276, 3, 391, 182, 3708, 3, 14, 15, 16, 17, 18, 226]
# 2           2  ...                       [19, 20, 384, 22, 60, 21, 5, 69, 150, 20348]
# 3           3  ...                          [72, 3, 8241, 63, 1216, 1216, 2, 8240, 5]
# 4           4  ...                                   [36, 2638, 100, 3821, 9, 41, 39]
#
# [5 rows x 9 columns]

# %%
df_preprocessed = df_clean.drop(columns=['clean_question1', 'clean_question2'])
df_preprocessed.to_csv('train_preprocessed.csv')

# %%
df_preprocessed = pd.read_csv(os.path.join(ROOT_DIR,'train_preprocessed.csv'))
df_preprocessed.head()
# Out:
#    Unnamed: 0  ...                                                          question2
# 0           0  ...                         [1, 2, 3, 4, 5, 4, 6, 7, 8, 9, 1454, 2291]
# 1           1  ...  [1, 100, 259, 276, 3, 391, 182, 3708, 3, 14, 15, 16, 17, 18, 226]
# 2           2  ...                       [19, 20, 384, 22, 60, 21, 5, 69, 150, 20348]
# 3           3  ...                          [72, 3, 8241, 63, 1216, 1216, 2, 8240, 5]
# 4           4  ...                                   [36, 2638, 100, 3821, 9, 41, 39]
#
# [5 rows x 8 columns]

# %% [markdown]
# # Setup pretrained embedding

# %%
import numpy as np
import torch.nn as nn
from gensim.models import KeyedVectors

# %%
embedding_dim = 200
vocab_size = len(token2Id.keys())+1
print(vocab_size)
# Out:
# 22812

# %%
w2v = KeyedVectors.load('w2v-200d.kv')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
weights_matrix = np.random.rand(vocab_size, embedding_dim)
for token, idx in token2Id.items():
  if token in w2v.vocab:
        weights_matrix[idx] = w2v[token]

np.save('pretrained_emb.npy', weights_matrix)
weights_matrix.shape
# Out:
# (22812, 200)
